# %%
import pandas as pd
df1 = pd.read_excel('DataForTable2.1.xls')
df2 = pd.read_excel('Appendix_2_Data_for_Figure_2.1.xls')
df3 = pd.read_excel('GDP.MKTP.CD_DS2_en_excel_v2_4701247.xls',sheet_name="Data",header=3)
df4 = pd.read_excel('GDP per capita + inflation.xlsx')
df5 = pd.read_excel('happiness index.xlsx')

# %%
# pip install --upgrade xlrd
df1
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df2
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland           7.8210      7.886425     7.755575
# 1       2      Denmark           7.6362      7.709897     7.562503
# 2       3      Iceland           7.5575      7.651076     7.463924
# 3       4  Switzerland           7.5116      7.586394     7.436806
# 4       5  Netherlands           7.4149      7.471265     7.358534
# ..    ...          ...              ...           ...          ...
# 142   143      Rwanda*           3.2682      3.462218     3.074182
# 143   144     Zimbabwe           2.9951      3.109822     2.880378
# 144   145      Lebanon           2.9553      3.048951     2.861649
# 145   146  Afghanistan           2.4038      2.468731     2.338869
# 146   147           xx              NaN           NaN          NaN
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                      2.518052                      1.891628
# ...

# %%
df3
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
df4
# Out:
#      country name  year  GDP per capita (USD)  \
# 0   United States  2012          51784.418574
# 1   United States  2013          53291.127689
# 2   United States  2014          55123.849787
# 3   United States  2015          56762.729452
# 4   United States  2016          57866.744934
# ..            ...   ...                   ...
# 95         Israel  2017          40774.129607
# 96         Israel  2018          42063.453127
# 97         Israel  2019          43951.247731
# 98         Israel  2020          44177.571225
# 99         Israel  2021          51430.079681
#
#     rate of inflation (%) CPI Annual Percent Change
# 0                                          2.069337
# 1                                          1.464833
# 2                                          1.622223
# 3                                          0.118627
# 4                                          1.261583
# ..                                              ...
# ...

# %%
df5
# Out:
#      Country name  year  happiness score  Healthy life expectancy at birth
# 0   United States  2012           7.0820                         66.660004
# 1   United States  2013           7.1005                         66.639999
# 2   United States  2014           7.1190                         66.620003
# 3   United States  2015           7.1040                         66.599998
# 4   United States  2016           6.9930                         66.474998
# ..            ...   ...              ...                               ...
# 95         Israel  2017           7.1900                         72.099998
# 96         Israel  2018           7.1387                         72.250000
# 97         Israel  2019           7.1290                         72.400002
# 98         Israel  2020           7.1570                         72.550003
# 99         Israel  2021           7.3638                         72.699997
#
# [100 rows x 4 columns]

# %%
df5.rename(columns = {'Country name':'country name'}, inplace = True)
df6 = pd.merge(df4,df5,on=('country name','year'))
df6
# Out:
#      country name  year  GDP per capita (USD)  \
# 0   United States  2012          51784.418574
# 1   United States  2013          53291.127689
# 2   United States  2014          55123.849787
# 3   United States  2015          56762.729452
# 4   United States  2016          57866.744934
# ..            ...   ...                   ...
# 95         Israel  2017          40774.129607
# 96         Israel  2018          42063.453127
# 97         Israel  2019          43951.247731
# 98         Israel  2020          44177.571225
# 99         Israel  2021          51430.079681
#
#     rate of inflation (%) CPI Annual Percent Change  happiness score  \
# 0                                          2.069337           7.0820
# 1                                          1.464833           7.1005
# 2                                          1.622223           7.1190
# 3                                          0.118627           7.1040
# ...

# %%
#There is a spelling mistake in df6. Correct it here. 
df6.loc[df6['country name'] == 'United Kindom','country name'] = 'United Kingdom'

# %%
df1.set_index('Country name', inplace=True)

# %%
df1 = df1.loc[['United States','China','Russia','Germany','United Kingdom','South Korea','France','Japan',
               'United Arab Emirates','Israel']]
df1 = df1.loc[df1['year'] >= 2000]
df1
# Out:
#                year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# United States  2006     7.181794           10.921763        0.964572
# United States  2007     7.512688           10.930840             NaN
# United States  2008     7.280386           10.920015        0.952587
# United States  2009     7.158032           10.885554        0.911794
# United States  2010     7.163616           10.902573        0.926159
# ...             ...          ...                 ...             ...
# Israel         2017     7.331036           10.574422        0.916441
# Israel         2018     6.927179           10.594217        0.909595
# Israel         2019     7.331780           10.612169        0.946011
# Israel         2020     7.194928           10.572567        0.959072
# Israel         2021     7.577528           10.616640        0.916583
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# ...

# %%
df2.set_index('Country', inplace=True)

# %%
df2 = df2.loc[['United States','China','Russia','Germany','United Kingdom','South Korea','France','Japan',
               'United Arab Emirates','Israel']]
df2
# Out:
#                       RANK  Happiness score  Whisker-high  Whisker-low  \
# Country
# United States           16           6.9768      7.065357     6.888243
# China                   72           5.5853      5.650282     5.520318
# Russia                  80           5.4586      5.525054     5.392146
# Germany                 14           7.0341      7.121579     6.946621
# United Kingdom          17           6.9425      7.017687     6.867313
# South Korea             59           5.9351      6.020747     5.849453
# France                  20           6.6867      6.758275     6.615125
# Japan                   54           6.0389      6.118531     5.959269
# United Arab Emirates    24           6.5760      6.660160     6.491840
# Israel                   9           7.3638      7.426288     7.301312
#
#                       Dystopia (1.83) + residual  \
# Country
# United States                           2.213618
# China                                   1.515917
# ...

# %%
df3.set_index('Country Name', inplace=True)

# %%
df3 = df3.loc[['United States','China','Russian Federation','Germany','United Kingdom','Korea, Rep.','France','Japan',
               'United Arab Emirates','Israel']]
df3
# Out:
#                      Country Code     Indicator Name  Indicator Code  \
# Country Name
# United States                 USA  GDP (current US$)  NY.GDP.MKTP.CD
# China                         CHN  GDP (current US$)  NY.GDP.MKTP.CD
# Russian Federation            RUS  GDP (current US$)  NY.GDP.MKTP.CD
# Germany                       DEU  GDP (current US$)  NY.GDP.MKTP.CD
# United Kingdom                GBR  GDP (current US$)  NY.GDP.MKTP.CD
# Korea, Rep.                   KOR  GDP (current US$)  NY.GDP.MKTP.CD
# France                        FRA  GDP (current US$)  NY.GDP.MKTP.CD
# Japan                         JPN  GDP (current US$)  NY.GDP.MKTP.CD
# United Arab Emirates          ARE  GDP (current US$)  NY.GDP.MKTP.CD
# Israel                        ISR  GDP (current US$)  NY.GDP.MKTP.CD
#
#                               1960          1961          1962          1963  \
# Country Name
# United States         5.433000e+11  5.633000e+11  6.051000e+11  6.386000e+11
# ...

# %%
df3.drop(['Country Code','Indicator Name','Indicator Code'],axis=1,inplace=True)
df3
# Out:
#                               1960          1961          1962          1963  \
# Country Name
# United States         5.433000e+11  5.633000e+11  6.051000e+11  6.386000e+11
# China                 5.971647e+10  5.005687e+10  4.720936e+10  5.070680e+10
# Russian Federation             NaN           NaN           NaN           NaN
# Germany                        NaN           NaN           NaN           NaN
# United Kingdom        7.323397e+10  7.774197e+10  8.124756e+10  8.656196e+10
# Korea, Rep.           3.958191e+09  2.417558e+09  2.814319e+09  3.988785e+09
# France                6.222548e+10  6.746164e+10  7.560753e+10  8.475920e+10
# Japan                 4.430734e+10  5.350862e+10  6.072302e+10  6.949813e+10
# United Arab Emirates           NaN           NaN           NaN           NaN
# Israel                2.598500e+09  3.138500e+09  2.510000e+09  2.992333e+09
#
#                               1964          1965          1966          1967  \
# Country Name
# ...

# %%
df3.columns = df3.columns.map(int)
df3.columns.values
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
df3 = df3.loc[:,[column >= 2000 for column in df3.columns]]
df3 = df3.reset_index()
df3
# Out:
#            Country Name          2000          2001          2002  \
# 0         United States  1.025095e+13  1.058193e+13  1.092911e+13
# 1                 China  1.211347e+12  1.339396e+12  1.470550e+12
# 2    Russian Federation  2.597101e+11  3.066021e+11  3.454705e+11
# 3               Germany  1.947982e+12  1.945791e+12  2.078485e+12
# 4        United Kingdom  1.662127e+12  1.643908e+12  1.784077e+12
# 5           Korea, Rep.  5.761781e+11  5.476582e+11  6.272461e+11
# 6                France  1.365640e+12  1.377657e+12  1.501409e+12
# 7                 Japan  4.968359e+12  4.374712e+12  4.182846e+12
# 8  United Arab Emirates  1.043374e+11  1.033116e+11  1.098162e+11
# 9                Israel  1.324557e+11  1.308163e+11  1.211485e+11
#
#            2003          2004          2005          2006          2007  \
# 0  1.145644e+13  1.221719e+13  1.303920e+13  1.381559e+13  1.447423e+13
# 1  1.660288e+12  1.955347e+12  2.285966e+12  2.752132e+12  3.550343e+12
# ...

# %%
df3_new = pd.melt(df3, id_vars=['Country Name'], value_vars=[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021],
                 var_name='time',value_name='GDP')
df3_new
# Out:
#             Country Name  time           GDP
# 0          United States  2012  1.625397e+13
# 1                  China  2012  8.532230e+12
# 2     Russian Federation  2012  2.208296e+12
# 3                Germany  2012  3.527143e+12
# 4         United Kingdom  2012  2.719158e+12
# ..                   ...   ...           ...
# 95           Korea, Rep.  2021  1.798534e+12
# 96                France  2021  2.937473e+12
# 97                 Japan  2021  4.937422e+12
# 98  United Arab Emirates  2021           NaN
# 99                Israel  2021  4.815913e+11
#
# [100 rows x 3 columns]

# %%
df3 = df3_new
df3.rename(columns = {'Country Name':'country name'}, inplace = True)
df3.rename(columns = {'time':'year'}, inplace = True)
df3
# Out:
#             country name  year           GDP
# 0          United States  2012  1.625397e+13
# 1                  China  2012  8.532230e+12
# 2     Russian Federation  2012  2.208296e+12
# 3                Germany  2012  3.527143e+12
# 4         United Kingdom  2012  2.719158e+12
# ..                   ...   ...           ...
# 95           Korea, Rep.  2021  1.798534e+12
# 96                France  2021  2.937473e+12
# 97                 Japan  2021  4.937422e+12
# 98  United Arab Emirates  2021           NaN
# 99                Israel  2021  4.815913e+11
#
# [100 rows x 3 columns]

# %%
df6
# Out:
#      country name  year  GDP per capita (USD)  \
# 0   United States  2012          51784.418574
# 1   United States  2013          53291.127689
# 2   United States  2014          55123.849787
# 3   United States  2015          56762.729452
# 4   United States  2016          57866.744934
# ..            ...   ...                   ...
# 95         Israel  2017          40774.129607
# 96         Israel  2018          42063.453127
# 97         Israel  2019          43951.247731
# 98         Israel  2020          44177.571225
# 99         Israel  2021          51430.079681
#
#     rate of inflation (%) CPI Annual Percent Change  happiness score  \
# 0                                          2.069337           7.0820
# 1                                          1.464833           7.1005
# 2                                          1.622223           7.1190
# 3                                          0.118627           7.1040
# ...

# %%
merge3_6 = pd.merge(df3,df6,how='right',on=['country name','year'])
merge3_6
# Out:
# /Users/nedim/Library/Python/3.8/lib/python/site-packages/pandas/core/reshape/merge.py:916: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   key_col = Index(lvals).where(~mask_left, rvals)
#      country name    year           GDP  GDP per capita (USD)  \
# 0   United States  2012.0  1.625397e+13          51784.418574
# 1   United States  2013.0  1.684319e+13          53291.127689
# 2   United States  2014.0  1.755068e+13          55123.849787
# 3   United States  2015.0  1.820602e+13          56762.729452
# 4   United States  2016.0  1.869511e+13          57866.744934
# ..            ...     ...           ...                   ...
# 95         Israel  2017.0  3.552772e+11          40774.129607
# 96         Israel  2018.0  3.736412e+11          42063.453127
# 97         Israel  2019.0  3.979346e+11          43951.247731
# ...

# %%
df1 = df1.reset_index()
df1.rename(columns = {'Country name':'country name'}, inplace = True)
merge3_6_1 = pd.merge(merge3_6,df1,how='left',on=['country name','year'])
merge3_6_1
# Out:
#      country name    year           GDP  GDP per capita (USD)  \
# 0   United States  2012.0  1.625397e+13          51784.418574
# 1   United States  2013.0  1.684319e+13          53291.127689
# 2   United States  2014.0  1.755068e+13          55123.849787
# 3   United States  2015.0  1.820602e+13          56762.729452
# 4   United States  2016.0  1.869511e+13          57866.744934
# ..            ...     ...           ...                   ...
# 95         Israel  2017.0  3.552772e+11          40774.129607
# 96         Israel  2018.0  3.736412e+11          42063.453127
# 97         Israel  2019.0  3.979346e+11          43951.247731
# 98         Israel  2020.0  4.071007e+11          44177.571225
# 99         Israel  2021.0  4.815913e+11          51430.079681
#
#     rate of inflation (%) CPI Annual Percent Change  happiness score  \
# 0                                          2.069337           7.0820
# 1                                          1.464833           7.1005
# ...

# %%
#This is the merged dataframe for df1,df3,df4,and df5. NOT YET MERGED WITH df2
df1_3_4_5 = merge3_6_1
merge3_6_1.dropna()
#do groupby if you want to merge with df2.
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np


# Nedim and Ahmed:
# Working on validating that we furfill our regression model assumptions...let us know if this is the right approach
# link: https://www.jmp.com/en_us/statistics-knowledge-portal/what-is-regression/simple-linear-regression-assumptions.html

# the plots below are to see where we have linear relationships 

countries = ['United States','China','Russia','Germany','United Kingdom','South Korea','France','Japan',
               'United Arab Emirates','Israel']

# Not sure why United Kingdom is an empty dataframe
# Need to fix this >:(

#Note by Bill: United Kingdom was misspelled as Kindom in the xlsx files where df4 and df5 are from. 
#Just added one line to fix it. Now it should be good.
UK = merge3_6_1.loc[merge3_6_1['country name'] == 'United Kingdom']
# print(UK)

# for i in countries:
#     country = merge3_6_1.loc[merge3_6_1['country name'] == i]
#     plt.scatter(country['GDP per capita (USD)'], country['happiness score'], )
#     plt.title(i + ': happiness score vs. GDP per capita (USD)')
#     plt.xlabel('GDP per capita (USD)')
#     plt.ylabel('happiness score')
#     #plt.show()

# for i in countries:
#     country = merge3_6_1.loc[merge3_6_1['country name'] == i]
#     plt.scatter(country['GDP per capita (USD)'], country['Generosity'], )
#     plt.title(i + ': Generosity vs. GDP per capita (USD)')
#     plt.xlabel('GDP per capita (USD)')
#     plt.ylabel('Generosity')
#     #plt.show()

# for i in countries:
#     country = merge3_6_1.loc[merge3_6_1['country name'] == i]
#     plt.scatter(country['GDP per capita (USD)'], country['Freedom to make life choices'], )
#     plt.title(i + ': Freedom to make life choices vs. GDP per capita (USD)')
#     plt.xlabel('GDP per capita (USD)')
#     plt.ylabel('Freedom to make life choices')
#     #plt.show()
